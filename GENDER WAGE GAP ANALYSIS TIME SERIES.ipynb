# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_developeindex = pd.read_csv(r"C:\Users\preem\Desktop\PROJECT\DATA ANALYSIS\SORTED STATUS INDEX.csv",encoding='latin1')
df_developeindex
# Out:
#      Time  Female    Male  Wage gap         Country Country_developementindex
# 0    2010  1336.5  1490.5  0.103321         Croatia                Developing
# 1    2010   758.0   928.0  0.183190          Latvia                 Developed
# 2    2010  1201.5  1544.0  0.221826         Czechia                Developing
# 3    2010   176.0   181.0  0.027624     Timor-Leste                Developing
# 4    2010     2.5     4.0  0.375000         Liberia                Developing
# ..    ...     ...     ...       ...             ...                       ...
# 618  2019  1049.0  1078.5  0.027353         Romania                Developing
# 619  2019  2609.0  3783.0  0.310336  United Kingdom                 Developed
# 620  2019   156.5   165.0  0.051515           Kenya                Developing
# 621  2019   828.0   870.0  0.048276         Bolivia                Developing
# 622  2019   133.0   159.0  0.163522           Egypt                Developing
#
# [623 rows x 6 columns]

# %%
lp = sns.lineplot(x="Time",y="Wage gap",hue="Country_developementindex",data=df_developeindex,marker='o')
plt.xlim(2010,2019)
lp.legend(loc='upper right', bbox_to_anchor=(1.4, 1))
plt.plot()
save_results_to = "C:/Users/preem/Desktop/PROJECT/"
plt.savefig(save_results_to+"lineplot.png", dpi=100)
