# %%
#This is the notebook created for the project
#Will be updated in the future

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\preem\Desktop\DATA ANALYSIS\editedwages.csv")
df.head()
# Out:
#    year   gender  managers  professionals  techniciansandtradesworkers  \
# 0  2004  Females     26.14          29.02                        17.90
# 1  2005  Females     28.10          30.00                        18.86
# 2  2006  Females     28.60          30.56                        19.64
# 3  2007  Females     36.43          31.93                        20.98
# 4  2008  Females     32.68          32.93                        20.30
#
#    communityandpersonalserviceworkers  clericalandadministrativeworkers  \
# 0                               18.01                             19.98
# 1                               18.20                             20.95
# 2                               18.84                             21.73
# 3                               19.85                             23.27
# 4                               20.97                             23.67
#
#    salesworkers  machineryoperatorsanddrivers  labourers
# ...

# %%
df.describe()
# Out:
#               year   managers  professionals  techniciansandtradesworkers  \
# count    28.000000  28.000000      28.000000                    28.000000
# mean   2010.500000  39.241429      40.046429                    25.506429
# std       4.105101   6.965343       6.903319                     4.643698
# min    2004.000000  26.140000      29.020000                    17.900000
# 25%    2007.000000  34.132500      34.305000                    22.080000
# 50%    2010.500000  38.595000      39.175000                    24.390000
# 75%    2014.000000  44.267500      45.187500                    28.540000
# max    2017.000000  52.510000      52.910000                    34.250000
#
#        communityandpersonalserviceworkers  clericalandadministrativeworkers  \
# count                           28.000000                         28.000000
# mean                            25.147500                         28.888929
# ...

# %%
df[['gender','managers']]
# Out:
#      gender  managers
# 0   Females     26.14
# 1   Females     28.10
# 2   Females     28.60
# 3   Females     36.43
# 4   Females     32.68
# 5   Females     33.30
# 6   Females     34.41
# 7   Females     35.22
# 8   Females     36.24
# 9   Females     37.26
# 10  Females     42.63
# 11  Females     42.12
# 12  Females     44.35
# 13  Females     46.02
# 14    Males     33.02
# 15    Males     33.13
# 16    Males     35.16
# 17    Males     38.85
# 18    Males     38.34
# 19    Males     41.67
# 20    Males     41.28
# 21    Males     43.87
# 22    Males     44.24
# 23    Males     44.85
# 24    Males     49.55
# 25    Males     49.02
# 26    Males     49.77
# 27    Males     52.51

# %%
sns.boxplot(x='gender',y='managers',data = df) #boxplot based on the gender(male,female) vs. the hourly pay for the manager post
# Out:
# <AxesSubplot:xlabel='gender', ylabel='managers'>
